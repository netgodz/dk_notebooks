# %% [markdown]
# # 天气环流形势分析

# %%
# 设置图像显示在notebook中
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 亚欧区域形势场, 500hPa高度场,850hPa风场和海平面气压场

# %%
# 载入绘图函数
from nmc_met_map.synoptic import gh500_uv850_mslp

# %%
gh500_uv850_mslp('19062808', fhour=24, model='ECMWF')
